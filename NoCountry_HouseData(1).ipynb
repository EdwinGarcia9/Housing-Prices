# %% [markdown]
# <a href="https://colab.research.google.com/github/EdwinGarcia9/Housing-Prices/blob/main/NoCountry_HouseData(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias utilizadas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics as st
import seaborn as sns

# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##**1. Función de análisis.**
#
# ---

# %%
global df
def leer_describir(url):
  #Lectura de Datos Lima
  df= pd.read_csv(url)
  print(df.shape)
  print(df.dtypes)
  print('\n')
  #df_0= pd.DataFrame(df)
  print(df.head(5))
  return df

# %% [markdown]
# ##**2. New York.**
#
# ---

# %%
df_ny=leer_describir('/content/drive/MyDrive/Colab Notebooks/Data House/NY-House-Dataset.csv')
# Out:
# (4801, 17)
# BROKERTITLE                     object
# TYPE                            object
# PRICE                            int64
# BEDS                             int64
# BATH                           float64
# PROPERTYSQFT                   float64
# ADDRESS                         object
# STATE                           object
# MAIN_ADDRESS                    object
# ADMINISTRATIVE_AREA_LEVEL_2     object
# LOCALITY                        object
# SUBLOCALITY                     object
# STREET_NAME                     object
# LONG_NAME                       object
# FORMATTED_ADDRESS               object
# LATITUDE                       float64
# LONGITUDE                      float64
# dtype: object
#
#
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# ...

# %%
#Copia fuente New York
copy_df_ny= df_ny.copy()
copy_df_ny
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %% [markdown]
# ##**3- Chicago.**
#
# ---

# %%
df_chicago=leer_describir('/content/drive/MyDrive/Colab Notebooks/Data House/real_estate_data_chicago.csv')
# Out:
# (2000, 15)
# type              object
# text              object
# year_built       float64
# beds             float64
# baths            float64
# baths_full       float64
# baths_half       float64
# garage           float64
# lot_sqft         float64
# sqft             float64
# stories          float64
# lastSoldPrice    float64
# soldOn            object
# listPrice        float64
# status            object
# dtype: object
#
#
#             type                                               text  \
# 0  single_family  Come check out this amazing, move-in ready, 5 ...
# 1  single_family  Move in ready 2 story Mount Greenwood home on ...
# 2  single_family  Investor Special MONEY MAKING Gem. This is you...
# 3  single_family  Renovated Brick 1.5 story house with finished ...
# 4  single_family  This almost 3000sq foot home was thoughtfully ...
#
#    year_built  beds  baths  baths_full  baths_half  garage  lot_sqft    sqft  \
# ...

# %%
#Copia de fuente Chicago
copy_df_chicago= df_chicago.copy()
copy_df_chicago
# Out:
#                type                                               text  \
# 0     single_family  Come check out this amazing, move-in ready, 5 ...
# 1     single_family  Move in ready 2 story Mount Greenwood home on ...
# 2     single_family  Investor Special MONEY MAKING Gem. This is you...
# 3     single_family  Renovated Brick 1.5 story house with finished ...
# 4     single_family  This almost 3000sq foot home was thoughtfully ...
# ...             ...                                                ...
# 1995  single_family  WEST ELSDON BRICK SINGLE FAMILY RAISED RANCH H...
# 1996         condos  Welcome to your spacious three bedroom condo i...
# 1997         condos  Luxury Residence with jaw dropping City and Ri...
# 1998   multi_family  Welcome to this charming & RARE, meticulously ...
# 1999  single_family  Lovely 3 bedroom, 1.5 bath brick bungalow with...
#
#       year_built  beds  baths  baths_full  baths_half  garage  lot_sqft  \
# ...

# %% [markdown]
# ##**3.1- Transformación BD Chicago.**
#
# ---

# %%
#Selección de Variables | Columnas
df_chi_final= pd.DataFrame(copy_df_chicago[['lastSoldPrice','beds','baths','lot_sqft']])
df_chi_final
# Out:
#       lastSoldPrice  beds  baths  lot_sqft
# 0               NaN   4.0    4.0    5615.0
# 1          105000.0   4.0    3.0    6566.0
# 2           60000.0   4.0    2.0    5375.0
# 3          170000.0   4.0    3.0    6138.0
# 4               NaN   4.0    4.0    8476.0
# ...             ...   ...    ...       ...
# 1995       148000.0   3.0    2.0       NaN
# 1996            NaN   3.0    2.0       NaN
# 1997      1705000.0   3.0    3.0       NaN
# 1998            NaN   6.0    5.0    6200.0
# 1999        42500.0   3.0    2.0    4059.0
#
# [2000 rows x 4 columns]

# %% [markdown]
# Agregado de columna STATE a Dataset Chicago para luego unir con USA.

# %%
#Agregando columna STATE
df_chi_final = df_chi_final.assign(state='Chicago, CHI')
#Renombrado de columnas
df_chi_final= df_chi_final.rename(columns={'lastSoldPrice':'price', 'beds': 'bed','baths':'bath', 'lot_sqft':'size(feet)'})
df_chi_final
# Out:
#           price  bed  bath  size(feet)         state
# 0           NaN  4.0   4.0      5615.0  Chicago, CHI
# 1      105000.0  4.0   3.0      6566.0  Chicago, CHI
# 2       60000.0  4.0   2.0      5375.0  Chicago, CHI
# 3      170000.0  4.0   3.0      6138.0  Chicago, CHI
# 4           NaN  4.0   4.0      8476.0  Chicago, CHI
# ...         ...  ...   ...         ...           ...
# 1995   148000.0  3.0   2.0         NaN  Chicago, CHI
# 1996        NaN  3.0   2.0         NaN  Chicago, CHI
# 1997  1705000.0  3.0   3.0         NaN  Chicago, CHI
# 1998        NaN  6.0   5.0      6200.0  Chicago, CHI
# 1999    42500.0  3.0   2.0      4059.0  Chicago, CHI
#
# [2000 rows x 5 columns]

# %% [markdown]
# ##**4- Estados Unidos en General.**
#
# ---

# %%
#Lectura de datos USA.
df_usa=leer_describir('/content/drive/MyDrive/Colab Notebooks/Data House/real_state-usa-data.csv')
# Out:
# (2226382, 12)
# brokered_by       float64
# status             object
# price             float64
# bed               float64
# bath              float64
# acre_lot          float64
# street            float64
# city               object
# state              object
# zip_code          float64
# house_size        float64
# prev_sold_date     object
# dtype: object
#
#
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1    Adjuntas  Puerto Rico     601.0      1527.0            NaN
# ...

# %%
#Copia de datos USA
copy_df_usa= df_usa.copy()
copy_df_usa
# Out:
#          brokered_by    status     price  bed  bath  acre_lot     street  \
# 0           103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1            52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2           103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3            31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4            34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
# ...              ...       ...       ...  ...   ...       ...        ...
# 2226377      23009.0      sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0      sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0      sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0      sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0      sold  580000.0  5.0   3.0      0.31   307704.0
#
#                city        state  zip_code  house_size prev_sold_date
# ...

# %%
#Valores únicos en STATE. Comprobación del faltante de Chicago.
valores_unicos_state=copy_df_usa['state'].unique()
print(valores_unicos_state)
print('\n')
valores_unicos_state= pd.DataFrame(valores_unicos_state)
print(valores_unicos_state.value_counts())
print('\n')
print(f'Total de valores unicos en variable STATE:',valores_unicos_state.value_counts().sum())
# Out:
# ['Puerto Rico' 'Virgin Islands' 'Massachusetts' 'Connecticut'
#  'New Hampshire' 'Vermont' 'New Jersey' 'New York' 'South Carolina'
#  'Tennessee' 'Rhode Island' 'Virginia' 'Wyoming' 'Maine' 'Georgia'
#  'Pennsylvania' 'West Virginia' 'Delaware' 'Louisiana' 'Ohio' 'California'
#  'Colorado' 'Maryland' 'Missouri' 'District of Columbia' 'Wisconsin'
#  'North Carolina' 'Kentucky' 'Michigan' 'Mississippi' 'Florida' 'Alabama'
#  'New Brunswick' nan 'Texas' 'Arkansas' 'Idaho' 'Indiana' 'Illinois'
#  'New Mexico' 'Iowa' 'Minnesota' 'South Dakota' 'Nebraska' 'North Dakota'
#  'Montana' 'Oklahoma' 'Kansas' 'Oregon' 'Utah' 'Nevada' 'Washington'
#  'Arizona' 'Hawaii' 'Guam' 'Alaska']
#
#
# Alabama                 1
# Puerto Rico             1
# New Brunswick           1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# ...

# %% [markdown]
# ##**4.1- Tranformación Datos Estados Unidos**
#
# ---

# %%
#Selección de Variables | Columnas
df_usa_final = copy_df_usa[copy_df_usa['status'] == 'for_sale'][['price', 'bed', 'bath','house_size','state']]
df_usa_final
# Out:
#              price  bed  bath  house_size        state
# 0         105000.0  3.0   2.0       920.0  Puerto Rico
# 1          80000.0  4.0   2.0      1527.0  Puerto Rico
# 2          67000.0  2.0   1.0       748.0  Puerto Rico
# 3         145000.0  4.0   2.0      1800.0  Puerto Rico
# 4          65000.0  6.0   2.0         NaN  Puerto Rico
# ...            ...  ...   ...         ...          ...
# 1414368   299000.0  NaN   NaN         NaN       Alaska
# 1414369   299000.0  NaN   NaN         NaN       Alaska
# 1414370   199000.0  NaN   NaN         NaN       Alaska
# 1414371  1575000.0  NaN   NaN         NaN       Alaska
# 1414372  1575000.0  NaN   NaN         NaN       Alaska
#
# [1389306 rows x 5 columns]

# %%
#Comprobación de datos "for_sale"
cantidad_for_sale = copy_df_usa['status'].value_counts().get('for_sale', 0)
print("Cantidad de 'for sale':", cantidad_for_sale)
# Out:
# Cantidad de 'for sale': 1389306

# %%
#Demora de uso de funcion Lamda es de aproximadamente 3 minutos.
#df_usa_final = copy_df_usa.apply(lambda row: pd.DataFrame(copy_df_usa[['price', 'bed', 'bath','state','house_size']]) if row['status'] == 'for_sale' else row, axis=1)

# %%
#Renombrado de variables USA.
df_usa_final= df_usa_final.rename(columns={'house_size':'size(feet)'})
df_final=pd.concat([df_usa_final, df_chi_final])
df_final=df_final.reset_index(drop=True)
df_final
# Out:
#              price  bed  bath  size(feet)         state
# 0         105000.0  3.0   2.0       920.0   Puerto Rico
# 1          80000.0  4.0   2.0      1527.0   Puerto Rico
# 2          67000.0  2.0   1.0       748.0   Puerto Rico
# 3         145000.0  4.0   2.0      1800.0   Puerto Rico
# 4          65000.0  6.0   2.0         NaN   Puerto Rico
# ...            ...  ...   ...         ...           ...
# 1391301   148000.0  3.0   2.0         NaN  Chicago, CHI
# 1391302        NaN  3.0   2.0         NaN  Chicago, CHI
# 1391303  1705000.0  3.0   3.0         NaN  Chicago, CHI
# 1391304        NaN  6.0   5.0      6200.0  Chicago, CHI
# 1391305    42500.0  3.0   2.0      4059.0  Chicago, CHI
#
# [1391306 rows x 5 columns]

# %%
df_final.to_csv('/content/drive/MyDrive/Colab Notebooks/Data House/Data_Final_realE_USA(2).csv', index=True)
