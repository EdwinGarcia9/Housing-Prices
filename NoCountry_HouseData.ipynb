# %% [markdown]
# <a href="https://colab.research.google.com/github/EdwinGarcia9/Housing-Prices/blob/main/NoCountry_HouseData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias utilizadas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics as st
import seaborn as sns

# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Lectura de Datos Lima
df_LimaP= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data House/dataset.csv')
df_LimaP
# Out:
#                                                   title  \
# 0             Apartamento en alquiler en Ur. Santa Cruz
# 1                    Apartamento en alquiler en Cercado
# 2               Apartamento en alquiler en Ur. San Luis
# 3                  Apartamento en alquiler en Ur. Risso
# 4     Apartamento en alquiler en Ur. Chacarilla Del ...
# ...                                                 ...
# 1074             Apartamento en alquiler en San Eugenio
# 1075         Casa en alquiler en La Campestre La Laguna
# 1076                  Casa de playa en alquiler en Asia
# 1077         Casa en alquiler en La Campestre La Laguna
# 1078         Casa en alquiler en La Campestre La Laguna
#
#                                                location     price  \
# 0               Ur. Santa Cruz, Miraflores, Lima, Lima     USD900
# 1                Cercado, Arequipa, Arequipa, Arequipa   S/.3,100
# 2                   Ur. San Luis, Barranco, Lima, Lima     USD720
# ...

# %%
print(df_LimaP.shape)
print(df_LimaP.dtypes)
# Out:
# (1079, 12)
# title               object
# location            object
# price               object
# bedroom             object
# bathroom            object
# area                object
# year_contruction    object
# maintenance         object
# housing_type        object
# operation_type      object
# date_pub            object
# url                 object
# dtype: object

# %%
df_LimaP.head(5)
# Out:
#                                                title  \
# 0          Apartamento en alquiler en Ur. Santa Cruz
# 1                 Apartamento en alquiler en Cercado
# 2            Apartamento en alquiler en Ur. San Luis
# 3               Apartamento en alquiler en Ur. Risso
# 4  Apartamento en alquiler en Ur. Chacarilla Del ...
#
#                                             location     price        bedroom  \
# 0            Ur. Santa Cruz, Miraflores, Lima, Lima     USD900  2 dormitorios
# 1             Cercado, Arequipa, Arequipa, Arequipa   S/.3,100  3 dormitorios
# 2                Ur. San Luis, Barranco, Lima, Lima     USD720  2 dormitorios
# 3                      Ur. Risso, Lince, Lima, Lima   S/.2,600   1 dormitorio
# 4  Ur. Chacarilla Del Estanque, Santiago de Surco...  S/.2,300  2 dormitorios
#
#   bathroom    area year_contruction maintenance housing_type operation_type  \
# 0  2 baños  103 m²             2010         NaN  Apartamento       Alquiler
# ...

# %%
df_LimaP = pd.DataFrame(df_LimaP)
df_LimaP['operation_type'].unique()
# Out:
# array(['Alquiler'], dtype=object)

# %%
df_LimaP.groupby(['title', 'year_contruction']).agg({'price':['min','max']})
# Out:
#                                                                          price  \
#                                                                            min
# title                                              year_contruction
# Apartamento en alquiler en A.h la Planicie         2011               USD2,500
# Apartamento en alquiler en Ag. La Paz              2014               S/.1,750
# Apartamento en alquiler en Ah. Los Jazmines Del... 2019               S/.1,150
# Apartamento en alquiler en Ah. Moron               2011                 USD370
# Apartamento en alquiler en Ah. Nuevo Lurin I Etapa 2017                 S/.900
# ...                                                                        ...
# Oficina en alquiler en Progreso                    2003                 USD500
# Oficina en alquiler en San Felipe                  2010               USD8,000
# Oficina en alquiler en San Isidro                  83 m²                USD700
# ...

# %%
#Lectura de datos España
df_Esp= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data House/indicadores_del_sector_inmobiliario.csv', delimiter="\t")
df_Esp
# Out:
#     Año;"Periodo";"Nº compraventa";"Precio m2 (Notarios)";"Nº hipotecas";"Deuda inmobiliaria familias";"Índice precio (INE)"
# 0         2017;"Enero";"17,93";"2,8";"14,12";"-3,3";""
# 1         2017;"Febrero";"1,49";"6";"-2,04";"-3,26";""
# 2       2017;"Marzo";"28,17";"4,07";"19,52";"-3,04";""
# 3      2017;"Abril";"-8,12";"8,23";"-12,51";"-3,06";""
# 4          2017;"Mayo";"23,83";"3,8";"6,96";"-3,04";""
# ..                                                 ...
# 160                                             ;;;;;;
# 161                                             ;;;;;;
# 162  Url:"https://www.epdata.es/indicadores-sector-...
# 163       Titulo:"Indicadores del sector inmobiliario"
# 164                   Subtitulo:"Variación interanual"
#
# [165 rows x 1 columns]

# %%
print(df_Esp.shape)
print(df_Esp.dtypes)
# Out:
# (165, 1)
# Año;"Periodo";"Nº compraventa";"Precio m2 (Notarios)";"Nº hipotecas";"Deuda inmobiliaria familias";"Índice precio (INE)"    object
# dtype: object

# %%
df_Esp.head(5)
# Out:
#   Año;"Periodo";"Nº compraventa";"Precio m2 (Notarios)";"Nº hipotecas";"Deuda inmobiliaria familias";"Índice precio (INE)"
# 0       2017;"Enero";"17,93";"2,8";"14,12";"-3,3";""
# 1       2017;"Febrero";"1,49";"6";"-2,04";"-3,26";""
# 2     2017;"Marzo";"28,17";"4,07";"19,52";"-3,04";""
# 3    2017;"Abril";"-8,12";"8,23";"-12,51";"-3,06";""
# 4        2017;"Mayo";"23,83";"3,8";"6,96";"-3,04";""

# %%
global df
def leer_describir(url):
  #Lectura de Datos Lima
  df= pd.read_csv(url)
  print(df.shape)
  print(df.dtypes)
  print('\n')
  #df_0= pd.DataFrame(df)
  print(df.head(5))
  return df

# %%
df_chicago=leer_describir('/content/drive/MyDrive/Colab Notebooks/Data House/real_estate_data_chicago.csv')
# Out:
# (2000, 15)
# type              object
# text              object
# year_built       float64
# beds             float64
# baths            float64
# baths_full       float64
# baths_half       float64
# garage           float64
# lot_sqft         float64
# sqft             float64
# stories          float64
# lastSoldPrice    float64
# soldOn            object
# listPrice        float64
# status            object
# dtype: object
#
#
#             type                                               text  \
# 0  single_family  Come check out this amazing, move-in ready, 5 ...
# 1  single_family  Move in ready 2 story Mount Greenwood home on ...
# 2  single_family  Investor Special MONEY MAKING Gem. This is you...
# 3  single_family  Renovated Brick 1.5 story house with finished ...
# 4  single_family  This almost 3000sq foot home was thoughtfully ...
#
#    year_built  beds  baths  baths_full  baths_half  garage  lot_sqft    sqft  \
# ...

# %%
#Copia de fuente Chicago
copy_df_chicago= df_chicago.copy()
copy_df_chicago
# Out:
#                type                                               text  \
# 0     single_family  Come check out this amazing, move-in ready, 5 ...
# 1     single_family  Move in ready 2 story Mount Greenwood home on ...
# 2     single_family  Investor Special MONEY MAKING Gem. This is you...
# 3     single_family  Renovated Brick 1.5 story house with finished ...
# 4     single_family  This almost 3000sq foot home was thoughtfully ...
# ...             ...                                                ...
# 1995  single_family  WEST ELSDON BRICK SINGLE FAMILY RAISED RANCH H...
# 1996         condos  Welcome to your spacious three bedroom condo i...
# 1997         condos  Luxury Residence with jaw dropping City and Ri...
# 1998   multi_family  Welcome to this charming & RARE, meticulously ...
# 1999  single_family  Lovely 3 bedroom, 1.5 bath brick bungalow with...
#
#       year_built  beds  baths  baths_full  baths_half  garage  lot_sqft  \
# ...

# %%
df_ny=leer_describir('/content/drive/MyDrive/Colab Notebooks/Data House/NY-House-Dataset.csv')
# Out:
# (4801, 17)
# BROKERTITLE                     object
# TYPE                            object
# PRICE                            int64
# BEDS                             int64
# BATH                           float64
# PROPERTYSQFT                   float64
# ADDRESS                         object
# STATE                           object
# MAIN_ADDRESS                    object
# ADMINISTRATIVE_AREA_LEVEL_2     object
# LOCALITY                        object
# SUBLOCALITY                     object
# STREET_NAME                     object
# LONG_NAME                       object
# FORMATTED_ADDRESS               object
# LATITUDE                       float64
# LONGITUDE                      float64
# dtype: object
#
#
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# ...

# %%
#Copia fuente New York
copy_df_ny= df_ny.copy()
copy_df_ny
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %%
df_usa=leer_describir('/content/drive/MyDrive/Colab Notebooks/Data House/real_state-usa-data.csv')
# Out:
# (2226382, 12)
# brokered_by       float64
# status             object
# price             float64
# bed               float64
# bath              float64
# acre_lot          float64
# street            float64
# city               object
# state              object
# zip_code          float64
# house_size        float64
# prev_sold_date     object
# dtype: object
#
#
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1    Adjuntas  Puerto Rico     601.0      1527.0            NaN
# ...

# %%
copy_df_usa= df_usa.copy()

# %%
valores_unicos_state=copy_df_usa['state'].unique()
print(valores_unicos_state)
print('\n')
valores_unicos_state= pd.DataFrame(valores_unicos_state)
print(valores_unicos_state.value_counts())
print('\n')
print(f'Total de valores unicos en variable STATE:',valores_unicos_state.value_counts().sum())
# Out:
# ['Puerto Rico' 'Virgin Islands' 'Massachusetts' 'Connecticut'
#  'New Hampshire' 'Vermont' 'New Jersey' 'New York' 'South Carolina'
#  'Tennessee' 'Rhode Island' 'Virginia' 'Wyoming' 'Maine' 'Georgia'
#  'Pennsylvania' 'West Virginia' 'Delaware' 'Louisiana' 'Ohio' 'California'
#  'Colorado' 'Maryland' 'Missouri' 'District of Columbia' 'Wisconsin'
#  'North Carolina' 'Kentucky' 'Michigan' 'Mississippi' 'Florida' 'Alabama'
#  'New Brunswick' nan 'Texas' 'Arkansas' 'Idaho' 'Indiana' 'Illinois'
#  'New Mexico' 'Iowa' 'Minnesota' 'South Dakota' 'Nebraska' 'North Dakota'
#  'Montana' 'Oklahoma' 'Kansas' 'Oregon' 'Utah' 'Nevada' 'Washington'
#  'Arizona' 'Hawaii' 'Guam' 'Alaska']
#
#
# Alabama                 1
# Puerto Rico             1
# New Brunswick           1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# ...

# %% [markdown]
# Agregado de columna STATE a Dataset USA

# %%
df_chi_final= pd.DataFrame(copy_df_chicago[['lastSoldPrice','beds','baths']])
df_chi_final
# Out:
#       lastSoldPrice  beds  baths
# 0               NaN   4.0    4.0
# 1          105000.0   4.0    3.0
# 2           60000.0   4.0    2.0
# 3          170000.0   4.0    3.0
# 4               NaN   4.0    4.0
# ...             ...   ...    ...
# 1995       148000.0   3.0    2.0
# 1996            NaN   3.0    2.0
# 1997      1705000.0   3.0    3.0
# 1998            NaN   6.0    5.0
# 1999        42500.0   3.0    2.0
#
# [2000 rows x 3 columns]

# %%
df_chi_final = df_chi_final.assign(state='Chicago, CHI')
df_chi_final= df_chi_final.rename(columns={'lastSoldPrice':'precio', 'beds': 'bed','baths':'bath'})
df_chi_final
# Out:
#          precio  bed  bath         state
# 0           NaN  4.0   4.0  Chicago, CHI
# 1      105000.0  4.0   3.0  Chicago, CHI
# 2       60000.0  4.0   2.0  Chicago, CHI
# 3      170000.0  4.0   3.0  Chicago, CHI
# 4           NaN  4.0   4.0  Chicago, CHI
# ...         ...  ...   ...           ...
# 1995   148000.0  3.0   2.0  Chicago, CHI
# 1996        NaN  3.0   2.0  Chicago, CHI
# 1997  1705000.0  3.0   3.0  Chicago, CHI
# 1998        NaN  6.0   5.0  Chicago, CHI
# 1999    42500.0  3.0   2.0  Chicago, CHI
#
# [2000 rows x 4 columns]

# %%
df_usa_final = pd.DataFrame(copy_df_usa[['price', 'bed', 'bath','state']])
df_final=pd.concat([df_usa_final, df_chi_final])
df_final=df_final.reset_index(drop=True)
df_final
# Out:
#             price  bed  bath         state     precio
# 0        105000.0  3.0   2.0   Puerto Rico        NaN
# 1         80000.0  4.0   2.0   Puerto Rico        NaN
# 2         67000.0  2.0   1.0   Puerto Rico        NaN
# 3        145000.0  4.0   2.0   Puerto Rico        NaN
# 4         65000.0  6.0   2.0   Puerto Rico        NaN
# ...           ...  ...   ...           ...        ...
# 2228377       NaN  3.0   2.0  Chicago, CHI   148000.0
# 2228378       NaN  3.0   2.0  Chicago, CHI        NaN
# 2228379       NaN  3.0   3.0  Chicago, CHI  1705000.0
# 2228380       NaN  6.0   5.0  Chicago, CHI        NaN
# 2228381       NaN  3.0   2.0  Chicago, CHI    42500.0
#
# [2228382 rows x 5 columns]

# %%
df_final.to_csv('/content/drive/MyDrive/Colab Notebooks/Data House/Data_Final_realE_USA.csv', index=True)
